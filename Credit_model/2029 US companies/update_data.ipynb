# %% [markdown]
# alphavantage api : X3QE1GA6K6CWOJ34

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=AAPL&apikey=X3QE1GA6K6CWOJ34'
r = requests.get(url)
data = r.json()

data
# Out:
# {'symbol': 'AAPL',
#  'annualReports': [{'fiscalDateEnding': '2025-09-30',
#    'reportedCurrency': 'USD',
#    'grossProfit': '195201000000',
#    'totalRevenue': '416161000000',
#    'costOfRevenue': '220960000000',
#    'costofGoodsAndServicesSold': '220960000000',
#    'operatingIncome': '133050000000',
#    'sellingGeneralAndAdministrative': '27601000000',
#    'researchAndDevelopment': '34550000000',
#    'operatingExpenses': '62151000000',
#    'investmentIncomeNet': 'None',
#    'netInterestIncome': 'None',
#    'interestIncome': 'None',
#    'interestExpense': 'None',
#    'nonInterestIncome': 'None',
#    'otherNonOperatingIncome': 'None',
#    'depreciation': 'None',
#    'depreciationAndAmortization': '11698000000',
#    'incomeBeforeTax': '132729000000',
#    'incomeTaxExpense': '20719000000',
#    'interestAndDebtExpense': 'None',
#    'netIncomeFromContinuingOperations': '112010000000',
#    'comprehensiveIncomeNetOfTax': 'None',
#    'ebit': '132729000000',
# ...
